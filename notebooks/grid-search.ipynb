# %%
import sys
sys.path.append("/Users/hzhan/documents/work/survival")

# %%
from src.model.model import *

# %%
model = Model()

# %%
model.run_cv()

# %%
model.plot_results()

# %%
model.rsf_model()
# Out:
# 0.6779350104821803

# %%
model.plot_survival()

# %%
model.plot_chf()
